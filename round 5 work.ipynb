# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('numerical_data_from_round4.csv')
data = data.drop(['Unnamed: 0'], axis=1)
data.head()
# Out:
#    customer lifetime value  income  monthly premium auto  \
# 0              4809.216960   48029                    61
# 1              2228.525238       0                    64
# 2             14947.917300   22139                   100
# 3             22332.439460   49078                    97
# 4              9025.067525   23675                   117
#
#    months since policy inception  number of open complaints  \
# 0                             52                        0.0
# 1                             26                        0.0
# 2                             31                        0.0
# 3                              3                        0.0
# 4                             31                        0.0
#
#    number of policies  total claim amount  response rate
# 0                   9          292.800000              0
# 1                   1          744.924331              0
# 2                   2          480.000000              0
# ...

# %%
#1 X-y split.

# %% [markdown]
# If we are looking to analyze the most profitable customers and how they interact, as the abstract in the read.me of Round 1 states, then 'customer lifetime value' would hold the target data.
#
# "The Customer Lifetime Value is the net present value of a customer. It considers the difference between the total amount of revenues from a customer and the companies expenses for this customer during the whole duration of relationship."

# %%
from sklearn import linear_model
y = data['customer lifetime value']
X = data.drop(['customer lifetime value'], axis=1)

lm = linear_model.LinearRegression()
model = lm.fit(X,y)
lm.score(X,y) #score is really low...
# Out:
# 0.16534529975186796

# %%
correlations_matrix = data.corr()
sns.heatmap(correlations_matrix, annot=True)
plt.show()

# %%
#2 Normalize (numerical).

# %%
data2 = data.copy()
data3 = data.copy()

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
#using MinMaxScaler
transformer = MinMaxScaler().fit(X)
x_normalized = transformer.transform(X) #applying method .tranform()
print(x_normalized.shape)
data_normalized = pd.DataFrame(x_normalized, columns=X.columns)

data_normalized.head()
# Out:
# (10910, 7)
#      income  monthly premium auto  months since policy inception  \
# 0  0.480381              0.000000                       0.525253
# 1  0.000000              0.012658                       0.262626
# 2  0.221432              0.164557                       0.313131
# 3  0.490873              0.151899                       0.030303
# 4  0.236795              0.236287                       0.313131
#
#    number of open complaints  number of policies  total claim amount  \
# 0                        0.0               1.000            0.101171
# 1                        0.0               0.000            0.257445
# 2                        0.0               0.125            0.165875
# 3                        0.0               0.125            0.167263
# 4                        0.0               0.750            0.244657
#
#    response rate
# 0            0.0
# 1            0.0
# 2            0.0
# 3            1.0
# 4            0.0

# %%
sns.displot(data_normalized['income'])
plt.show()

# %%
sns.displot(data_normalized['monthly premium auto'])
plt.show()

# %%
sns.displot(data_normalized['months since policy inception'])
plt.show()

# %%
sns.displot(data_normalized['number of open complaints'])
plt.show()

# %%
sns.displot(data_normalized['number of policies'])
plt.show()

# %%
sns.displot(data_normalized['total claim amount'])
plt.show()

# %%
sns.displot(data_normalized['response rate'])
plt.show()
